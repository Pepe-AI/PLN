# %%
import pandas as pd
import numpy as np

# %%
path="/content/drive/MyDrive/Escuela/6 Sexto/ANLP/Examen/dataset/dataset_1.csv"
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    indice              autor                         nombre  num_sentences  \
# 0       0  PerezGaldosBenito  el_19_de_marzo_y_el_2_de_mayo           3541
# 1       1  PerezGaldosBenito                      el_abuelo           6122
# 2       2  PerezGaldosBenito                 el_amigo_manso           4519
# 3       3  PerezGaldosBenito                      El abuelo           2760
# 4       4  PerezGaldosBenito     la_batalla_de_los_arapiles           5124
#
#    num_words  num_unique_words  num_stopwords  num_punctuation  \
# 0      80137             11704          31827            14876
# 1      84425             12157          27171            24607
# 2     106186             15082          39483            20812
# 3      73791             11211          29243            12391
# 4     107027             14091          40279            22819
#
#    punctuation_to_sentence_ratio  unique_to_total_words_ratio  \
# 0                       4.201073                     0.146050
# 1                       4.019438                     0.143998
# 2                       4.605444                     0.142034
# 3                       4.489493                     0.151929
# 4                       4.453357                     0.131658
#
#    stopwords_to_total_words_ratio  num_syllables        FRE       FKGL
# 0                        0.397157         137624  38.575781  13.500996
# 1                        0.321836         138281  54.270080   9.115668
# 2                        0.371829         184732  35.806066  14.102578
# 3                        0.396295         129535  31.188640  15.551073
# 4                        0.376344         189006  36.233607  13.394477

# %%
data = data.drop('indice', axis=1)
data.corr()
# Out:
# <ipython-input-33-2eb05e35b2b7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                 num_sentences  num_words  num_unique_words  \
# num_sentences                        1.000000   0.958092          0.896125
# num_words                            0.958092   1.000000          0.958934
# num_unique_words                     0.896125   0.958934          1.000000
# num_stopwords                        0.925326   0.992869          0.956388
# num_punctuation                      0.951571   0.923630          0.912646
# punctuation_to_sentence_ratio       -0.400744  -0.322320         -0.163778
# unique_to_total_words_ratio         -0.838051  -0.843756         -0.814689
# stopwords_to_total_words_ratio      -0.439079  -0.241642         -0.217967
# num_syllables                        0.952276   0.998904          0.952768
# FRE                                  0.418021   0.217528          0.228699
# FKGL                                -0.541957  -0.332489         -0.299926
#
#                                 num_stopwords  num_punctuation  \
# num_sentences                        0.925326         0.951571
# num_words                            0.992869         0.923630
# num_unique_words                     0.956388         0.912646
# num_stopwords                        1.000000         0.887349
# num_punctuation                      0.887349         1.000000
# punctuation_to_sentence_ratio       -0.320843        -0.136329
# unique_to_total_words_ratio         -0.832324        -0.806314
# stopwords_to_total_words_ratio      -0.130889        -0.475645
# num_syllables                        0.993611         0.907635
# FRE                                  0.153999         0.484088
# FKGL                                -0.266119        -0.547127
#
#                                 punctuation_to_sentence_ratio  \
# num_sentences                                       -0.400744
# num_words                                           -0.322320
# num_unique_words                                    -0.163778
# num_stopwords                                       -0.320843
# num_punctuation                                     -0.136329
# punctuation_to_sentence_ratio                        1.000000
# unique_to_total_words_ratio                          0.356200
# stopwords_to_total_words_ratio                       0.062428
# num_syllables                                       -0.340829
# FRE                                                 -0.147317
# FKGL                                                 0.359385
#
#                                 unique_to_total_words_ratio  \
# num_sentences                                     -0.838051
# num_words                                         -0.843756
# num_unique_words                                  -0.814689
# num_stopwords                                     -0.832324
# num_punctuation                                   -0.806314
# punctuation_to_sentence_ratio                      0.356200
# unique_to_total_words_ratio                        1.000000
# stopwords_to_total_words_ratio                     0.268765
# num_syllables                                     -0.838739
# FRE                                               -0.407863
# FKGL                                               0.501804
#
#                                 stopwords_to_total_words_ratio  num_syllables  \
# num_sentences                                        -0.439079       0.952276
# num_words                                            -0.241642       0.998904
# num_unique_words                                     -0.217967       0.952768
# num_stopwords                                        -0.130889       0.993611
# num_punctuation                                      -0.475645       0.907635
# punctuation_to_sentence_ratio                         0.062428      -0.340829
# unique_to_total_words_ratio                           0.268765      -0.838739
# stopwords_to_total_words_ratio                        1.000000      -0.223516
# num_syllables                                        -0.223516       1.000000
# FRE                                                  -0.658008       0.183797
# FKGL                                                  0.684946      -0.307083
#
#                                      FRE      FKGL
# num_sentences                   0.418021 -0.541957
# num_words                       0.217528 -0.332489
# num_unique_words                0.228699 -0.299926
# num_stopwords                   0.153999 -0.266119
# num_punctuation                 0.484088 -0.547127
# punctuation_to_sentence_ratio  -0.147317  0.359385
# unique_to_total_words_ratio    -0.407863  0.501804
# stopwords_to_total_words_ratio -0.658008  0.684946
# num_syllables                   0.183797 -0.307083
# FRE                             1.000000 -0.962945
# FKGL                           -0.962945  1.000000
